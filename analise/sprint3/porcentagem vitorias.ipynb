# %% [markdown]
# # Análise dos maiores e menores vencedores
#     * Ranking da porcentagem de vitórias
#     * Ranking da porcentagem de derrotas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lic = pd.read_csv("propostas_licitacao.txt", sep="|", dtype={'cod_unidade_gestora': int,'numero_licitacao': str,'cod_tipo_licitacao': int,
                                                   'qtd_ofertada': int,'unidade_gestora': str, 'tipo_licitacao': str, 
                                                   'cpf_cnpj': str,'nome_proponente': str, 'situacao_proposta': str})

# %%
porcentagem = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100).round(1).astype(str) + '%')
                   .reset_index())
porcentagem
# Out:
#                                           nome_proponente  situacao_proposta  \
# 0                                CIRUFARMA COMERCIAL LTDA                985
# 1                          RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                            PNEUMAX LTDA                461
# 3                                   JOSE NERGINO SOBREIRA                395
# 4         TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                                VENDE TUDO MAGAZINE LTDA                343
# 6                                         DROGAFONTE LTDA                338
# 7                                 COMERCIAL MEDEIROS LTDA                328
# 8                          B J COMERCIO DE ALIMENTOS LTDA                328
# 9                                      CRM COMERCIAL LTDA                327
# 10                      ELMAR PROCESSAMENTO DE DADOS LTDA                322
# 11      NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
# 12                MEGA MASTER COMERCIAL DE ALIMENTOS LTDA                306
# 13                                     FIORI VEICOLO LTDA                299
# 14               LEIA COMERCIAL DE LIVROS E MAGAZINE LTDA                297
# 15                              CIRURGICA CAMPINENSE LTDA                285
# 16                                            FARMAGUEDES                265
# 17                              EDILANE DA COSTA CARVALHO                265
# 18                               NORDESTE HOSPITALAR LTDA                263
# 19                               DROGARIA DROGAVISTA LTDA                257
# 20                            CELIA FRANCISCO DE CARVALHO                256
# 21                          DENTALMED COMERCIO E REP LTDA                240
# 22             PONTUAL DISTRIBUIDORA DE MEDICAMENTOS LTDA                238
# 23      SUPRIMAIS COMERCIO E SERVICOS DE INFORMATICA LTDA                234
# 24       LECITA COMÉRCIO DE MATERIAL PARA ESCRITÓRIO LTDA                233
# 25                                  MD DISTRIBUIDORA LTDA                231
# 26         THOMAS JOSE BELTRAO DE ARAUJO ALBUQUERQUE - ME                226
# 27                             MEDFARMACY HOSPITALAR LTDA                225
# 28                              ADERALDO SERAFIM DE SOUSA                224
# 29                            IRAMILTON SATIRO DA NOBREGA                221
# ...                                                   ...                ...
# 118703                  JOSE FIRMINO DO NASCIMENTO SANTOS                  1
# 118704                      LAURINDO LOPES  DO NASCIMENTO                  1
# 118705                             GILVANA GERVASIO GOMES                  1
# 118706                                 CONSTRUTORA LINEAR                  1
# 118707                       ORLANDO VILLARIM MEIRA FILHO                  1
# 118708                                 JOSE JOEL SOBRINHO                  1
# 118709                           Jucelino Dias de Almeida                  1
# 118710                        FF LOCADORA DE VEICULO LTDA                  1
# 118711                               JOÁO BATISTA CANDIDO                  1
# 118712               Comercial de Alimentos Savassi Ltda.                  1
# 118713                          B.R.A. COMERCIO E SERVICO                  1
# 118714                      WANDERSON GONÇALVES ARRUDA ME                  1
# 118715                             ANTONIO MÁRIO DA SILVA                  1
# 118716                         ABIDENICO CANDIDO DA SILVA                  1
# 118717                       DOUGLAS FERREIRA DE MEDEIROS                  1
# 118718                             Jose Ferreira Sobrinho                  1
# 118725  COLONIA DE PESCADORES E AQUICULTORES Z 25 COOP...                  1
# 118726                                    Hidrometro Ltda                  1
# 118727                            ALUIZIO LUDGERO BESERRA                  1
# 118728                            ALDO VANDERLEY DA SILVA                  1
# 118729                  GEMA Construções e Comércio Ltda.                  1
# 118730                         GLAUCIO DE LUCENA CORDEIRO                  1
# 118731  EPS-EMPRESA DE PRESTAÇÃO DE SERV. DE APOIO MAN...                  1
# 118732                              SOMAR CONSTRUTOA LTDA                  1
#
#         Perdedora  Pesquisado  Vencedora
# 0             5.7         0.1       94.2
# 1            34.2         0.0       65.8
# 2            50.1         0.0       49.9
# 3             7.1         0.0       92.9
# 4             7.2         0.0       92.8
# 5            29.4         0.0       70.6
# 6             3.0         0.0       97.0
# 7            23.2         0.0       76.8
# 8             9.8         0.0       90.2
# 9             8.0         0.0       92.0
# 10           21.7         0.0       78.3
# 11            1.3         0.0       98.7
# 12           40.2         0.0       59.8
# 13            8.7         0.0       91.3
# 14           20.5         0.0       79.5
# 15           33.3         0.0       66.7
# 16           16.6         0.0       83.4
# 17            6.4         0.0       93.6
# 18           18.3         0.4       81.4
# 19           39.3         0.0       60.7
# 20            6.2         0.0       93.8
# 21            6.2         0.0       93.8
# 22           10.9         0.0       89.1
# 23           18.8         0.0       81.2
# 24           10.3         0.0       89.7
# 25           44.2         0.0       55.8
# 26            9.7         0.0       90.3
# 27           13.8         0.0       86.2
# 28           68.8         0.4       30.8
# 29            0.9         0.0       99.1
# ...           ...         ...        ...
# 118703        0.0         0.0      100.0
# 118704        0.0         0.0      100.0
# 118705        0.0         0.0      100.0
# 118706        0.0         0.0      100.0
# 118707        0.0         0.0      100.0
# 118708        0.0         0.0      100.0
# 118709        0.0         0.0      100.0
# 118710      100.0         0.0        0.0
# 118711      100.0         0.0        0.0
# 118712        0.0         0.0      100.0
# 118713      100.0         0.0        0.0
# 118714        0.0         0.0      100.0
# 118715        0.0         0.0      100.0
# 118716        0.0         0.0      100.0
# 118717        0.0         0.0      100.0
# 118718        0.0         0.0      100.0
# 118719        0.0         0.0      100.0
# 118720      100.0         0.0        0.0
# 118721      100.0         0.0        0.0
# 118722      100.0         0.0        0.0
# 118723      100.0         0.0        0.0
# 118724        0.0         0.0      100.0
# 118725        0.0         0.0      100.0
# 118726      100.0         0.0        0.0
# 118727        0.0         0.0      100.0
# 118728        0.0         0.0      100.0
# 118729        0.0         0.0      100.0
# 118730      100.0         0.0        0.0
# 118731      100.0         0.0        0.0
# 118732      100.0         0.0        0.0
#
# [118733 rows x 5 columns]

# %%
propostas = porcentagem[:10]
propostas
# Out:
#                                    nome_proponente  situacao_proposta  \
# 0                         CIRUFARMA COMERCIAL LTDA                985
# 1                   RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                     PNEUMAX LTDA                461
# 3                            JOSE NERGINO SOBREIRA                395
# 4  TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                         VENDE TUDO MAGAZINE LTDA                343
# 6                                  DROGAFONTE LTDA                338
# 7                          COMERCIAL MEDEIROS LTDA                328
# 8                   B J COMERCIO DE ALIMENTOS LTDA                328
# 9                               CRM COMERCIAL LTDA                327
#
#    Perdedora  Pesquisado  Vencedora
# 0        5.7         0.1       94.2
# 1       34.2         0.0       65.8
# 2       50.1         0.0       49.9
# 3        7.1         0.0       92.9
# 4        7.2         0.0       92.8
# 5       29.4         0.0       70.6
# 6        3.0         0.0       97.0
# 7       23.2         0.0       76.8
# 8        9.8         0.0       90.2
# 9        8.0         0.0       92.0

# %%
propostas = porcentagem[:10]
propostas
# Out:
#                                    nome_proponente  situacao_proposta  \
# 0                         CIRUFARMA COMERCIAL LTDA                985
# 1                   RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                     PNEUMAX LTDA                461
# 3                            JOSE NERGINO SOBREIRA                395
# 4  TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                         VENDE TUDO MAGAZINE LTDA                343
# 6                                  DROGAFONTE LTDA                338
# 7                          COMERCIAL MEDEIROS LTDA                328
# 8                   B J COMERCIO DE ALIMENTOS LTDA                328
# 9                               CRM COMERCIAL LTDA                327
#
#   Perdedora Pesquisado Vencedora
# 0      5.7%       0.1%     94.2%
# 1     34.2%       0.0%     65.8%
# 2     50.1%       0.0%     49.9%
# 3      7.1%       0.0%     92.9%
# 4      7.2%       0.0%     92.8%
# 5     29.4%       0.0%     70.6%
# 6      3.0%       0.0%     97.0%
# 7     23.2%       0.0%     76.8%
# 8      9.8%       0.0%     90.2%
# 9      8.0%       0.0%     92.0%

# %%
propostas.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
#bichado
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou
# Out:
#                                           nome_proponente  situacao_proposta  \
# 48235               ANTONIO REGINALDO LOPES CASIMIRO - ME                  2
# 45081                              RENILSON BATISTA SILVA                  2
# 73498                           JOSE IVAN FERREIRA MORAIZ                  1
# 113502                        FRANCISCO IRANILDO SARMENTO                  1
# 45069                                CLAUDIA DIAS TIMOTEO                  2
# 45070                   FELIPE GONÇALVES GARCIA DE ARAUJO                  2
# 45071   MARIA ELICENIA PEREIRA LIETE - POLYCLAR P. & P...                  2
# 45072   MAN LATIN AMÉRICA INDÚSTRIA E COMERCIO DE VEÍC...                  2
# 113501    CONSULTÓRIO MÉDICO DR. GERALDO ARNAUD EIRELI-ME                  1
# 45074                          POSTO COMBUSTIVEIS GT LTDA                  2
#
#         Perdedora  Pesquisado  Vencedora
# 48235         0.0         0.0      100.0
# 45081         0.0         0.0      100.0
# 73498         0.0         0.0      100.0
# 113502        0.0         0.0      100.0
# 45069         0.0         0.0      100.0
# 45070         0.0         0.0      100.0
# 45071         0.0         0.0      100.0
# 45072         0.0         0.0      100.0
# 113501        0.0         0.0      100.0
# 45074         0.0         0.0      100.0

# %%
#bichado
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou
# Out:
#                                        nome_proponente  situacao_proposta  \
# 93                         RITA DE ANDRADE VIEIRA - ME                139
# 113                     COMPANHIA PARAIBANA DE COMÉDIA                121
# 29                         IRAMILTON SATIRO DA NOBREGA                221
# 35             JOSE WALTER DA COSTA ME - J C PRODUÇÕES                203
# 45                              ELFA MEDICAMENTOS LTDA                189
# 235                 INITUS CONSULTORES ASSOCIADOS LTDA                 85
# 273                       JOSELIA MARIA DE SOUSA RAMOS                 80
# 246               FRANCISCO VIVALDO JACOME DE OLIVEIRA                 84
# 242                                          CIRUFARMA                 84
# 11   NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
#
#     Perdedora Pesquisado Vencedora
# 93       0.7%       0.0%     99.3%
# 113      0.8%       0.0%     99.2%
# 29       0.9%       0.0%     99.1%
# 35       1.0%       0.0%     99.0%
# 45       1.1%       0.0%     98.9%
# 235      1.2%       0.0%     98.8%
# 273      1.2%       0.0%     98.8%
# 246      1.2%       0.0%     98.8%
# 242      1.2%       0.0%     98.8%
# 11       1.3%       0.0%     98.7%

# %%
ganhou.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
perdeu = porcentagem.sort_values(by='Perdedora', ascending=False)[:10]
perdeu
# Out:
#                                nome_proponente  situacao_proposta  Perdedora  \
# 59366  MULTICONSULT PLANEJ. ENG. E ARQUITETURA                  2      100.0
# 68527                JOSE DOS SANTOS BEZERRA *                  1      100.0
# 68899                 NERVALDO DA COSTA PESSOA                  1      100.0
# 68904                       Erica Elisa NicKel                  1      100.0
# 68908       KM DISTRIBUIDORA DE ALIMENTOS LTDA                  1      100.0
# 68909                 CASA DAS FLORES LTDA  ME                  1      100.0
# 68910                 JOSE XAVIER DE ARAUJO ME                  1      100.0
# 68911       Centauros Produções e Eventos Ltda                  1      100.0
# 68912                 Gustavo Gadelha Suassuna                  1      100.0
# 68915                    JOSÉ ERONALDO DE MELO                  1      100.0
#
#        Pesquisado  Vencedora
# 59366         0.0        0.0
# 68527         0.0        0.0
# 68899         0.0        0.0
# 68904         0.0        0.0
# 68908         0.0        0.0
# 68909         0.0        0.0
# 68910         0.0        0.0
# 68911         0.0        0.0
# 68912         0.0        0.0
# 68915         0.0        0.0

# %%
perdeu = porcentagem.sort_values(by='Perdedora', ascending=False)[:10]
perdeu
# Out:
#                                  nome_proponente  situacao_proposta Perdedora  \
# 710                     TECNOVIDA COMERCIAL LTDA                 45     97.8%
# 720    F&B COMERCIO ATACADISTA DE ALIMENTOS LTDA                 45     97.8%
# 735                                     AC PNEUS                 44     97.7%
# 1269                  CONSTRUTORA CACHOEIRA LTDA                 32     96.9%
# 1369                       SETA CONSTRUCOES LTDA                 31     96.8%
# 262                      ERISVALDO GOMES DE MELO                 82     96.3%
# 1706                      PROCOM ENGENHARIA LTDA                 26     96.2%
# 1766                   AC COMÉRCIO DE PNEUS LTDA                 25     96.0%
# 1883             JONABIA NOBREGA DE LUCENA SILVA                 24     95.8%
# 1932  SÃO JOÉ EMPREENDIMENTOS DE CONTRUÇÕES LTDA                 24     95.8%
#
#      Pesquisado Vencedora
# 710        0.0%      2.2%
# 720        0.0%      2.2%
# 735        0.0%      2.3%
# 1269       0.0%      3.1%
# 1369       0.0%      3.2%
# 262        0.0%      3.7%
# 1706       0.0%      3.8%
# 1766       0.0%      4.0%
# 1883       0.0%      4.2%
# 1932       0.0%      4.2%

# %%
perdeu.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
perdeu.plot(x="nome_proponente", y=["Perdedora","Vencedora"], kind="barh").invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-219-a6b8b6528f69> in <module>
# ----> 1 perdeu.plot(x="nome_proponente", y=["Perdedora","Vencedora"], kind="barh").invert_yaxis()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
