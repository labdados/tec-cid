# %% [markdown]
# # Análise dos maiores e menores vencedores
#     * Ranking da porcentagem de vitórias
#     * Ranking da porcentagem de derrotas

# %% [markdown]
# ## Erros:
# * sem astype(str) o .info() de porcentagem mostra perdedora/vencedora como float, mas após o sort_values() pra ordenar pelas maiores perdedoras/vencedoras, o .info() mostra elas como string
# * há diferença nos resutados do sort_values() pra ordenar pelas maiores perdedoras/vencedoras ao fazer com e sem astype(str)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lic = pd.read_csv("propostas_licitacao.txt", sep="|", dtype={'cod_unidade_gestora': int,'numero_licitacao': str,'cod_tipo_licitacao': int,
                                                   'qtd_ofertada': int,'unidade_gestora': str, 'tipo_licitacao': str, 
                                                   'cpf_cnpj': str,'nome_proponente': str, 'situacao_proposta': str})

# %%
porcentagem = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100).round(1).astype(str) + '%')
                   .reset_index())
porcentagem
# Out:
#                                           nome_proponente  situacao_proposta  \
# 0                                CIRUFARMA COMERCIAL LTDA                985
# 1                          RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                            PNEUMAX LTDA                461
# 3                                   JOSE NERGINO SOBREIRA                395
# 4         TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                                VENDE TUDO MAGAZINE LTDA                343
# 6                                         DROGAFONTE LTDA                338
# 7                                 COMERCIAL MEDEIROS LTDA                328
# 8                          B J COMERCIO DE ALIMENTOS LTDA                328
# 9                                      CRM COMERCIAL LTDA                327
# 10                      ELMAR PROCESSAMENTO DE DADOS LTDA                322
# 11                MEGA MASTER COMERCIAL DE ALIMENTOS LTDA                306
# 12      NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
# 13                                     FIORI VEICOLO LTDA                299
# 14               LEIA COMERCIAL DE LIVROS E MAGAZINE LTDA                297
# 15                              CIRURGICA CAMPINENSE LTDA                285
# 16                              EDILANE DA COSTA CARVALHO                265
# 17                                            FARMAGUEDES                265
# 18                               NORDESTE HOSPITALAR LTDA                263
# 19                               DROGARIA DROGAVISTA LTDA                257
# 20                            CELIA FRANCISCO DE CARVALHO                256
# 21                          DENTALMED COMERCIO E REP LTDA                240
# 22             PONTUAL DISTRIBUIDORA DE MEDICAMENTOS LTDA                238
# 23      SUPRIMAIS COMERCIO E SERVICOS DE INFORMATICA LTDA                234
# 24       LECITA COMÉRCIO DE MATERIAL PARA ESCRITÓRIO LTDA                233
# 25                                  MD DISTRIBUIDORA LTDA                231
# 26         THOMAS JOSE BELTRAO DE ARAUJO ALBUQUERQUE - ME                226
# 27                             MEDFARMACY HOSPITALAR LTDA                225
# 28                              ADERALDO SERAFIM DE SOUSA                224
# 29                            IRAMILTON SATIRO DA NOBREGA                221
# ...                                                   ...                ...
# 118703                         PESQUEIRA DO NORDESTE-LTDA                  1
# 118704                     FRANKLIN DE OLIVEIRA CANTALICE                  1
# 118705  JUED COMERCIO E ASSISTENCIA DE EQUIPAMENTOS OD...                  1
# 118706                            JOSE ALEXANDRO DA SILVA                  1
# 118707                         FOLHA DE PESSOAL CLT SAUDE                  1
# 118708                     JAC-CONSTRUCOES E EVENTOS LTDA                  1
# 118709  MACIEL MARINHO SOCIEDADE INDIVIDUAL DE ADVOCAC...                  1
# 118710                             JOAO CANDIDO DA CASTRO                  1
# 118711                               OLI CONSTRUCOES LTDA                  1
# 118712  GEOVANE REFRIGERAÇÕES - VANDELÚCIA DE ARAÚJO R...                  1
# 118713                                 Ozias Bezerra Lima                  1
# 118714                   JOSE GABRIEL DE SOUZA DINIZ - ME                  1
# 118715                  INPREL CONSTRUÇÃO E SERVIÇOS LTDA                  1
# 118716            MANOEL JOSE DA SILVA PESSOA 05265992782                  1
# 118717                          ORLANDO INÁCIO DOS SANTOS                  1
# 118718                                 FERREIRA ADVOCACIA                  1
# 118719                  J & F PRESTADORA DE SERVIÇOS LTDA                  1
# 118720               JMS COMERCIO E SERVICOS PIRELLE - ME                  1
# 118721                                J. LIRA E CIA. LTDA                  1
# 118722  XMAIS MATERIAIS DE CONSTRUÇÃO LOC. INCORP. LTD...                  1
# 118723                       ROBERTO LUIZ NOBREGA CAMBOIM                  1
# 118724                         Gilson Marques de Oliveira                  1
# 118725                          PAULO CELESTINO DE PONTES                  1
# 118726                        PEDRO BARBOSA DO NASCIMENTO                  1
# 118727               GEOSISTEMAS ENG.E PLANEJAMENTO LTDA.                  1
# 118728      N.A.SOARES COMERCIO DE COMBUSTIVEL EIRELI EPP                  1
# 118729                         SILVIA ARAÚJO SIMPLICIO-ME                  1
# 118730    LOCADORA DE VEICULOS SANTA TEREZINHA EIRELI-EPP                  1
# 118731                       MANOEL RICARDO RAMALHO LEITE                  1
# 118732            MONIQUE POLIANA TORRES FRANÇAS DE BRITO                  1
#
#        Perdedora Pesquisado Vencedora
# 0           5.7%       0.1%     94.2%
# 1          34.2%       0.0%     65.8%
# 2          50.1%       0.0%     49.9%
# 3           7.1%       0.0%     92.9%
# 4           7.2%       0.0%     92.8%
# 5          29.4%       0.0%     70.6%
# 6           3.0%       0.0%     97.0%
# 7          23.2%       0.0%     76.8%
# 8           9.8%       0.0%     90.2%
# 9           8.0%       0.0%     92.0%
# 10         21.7%       0.0%     78.3%
# 11         40.2%       0.0%     59.8%
# 12          1.3%       0.0%     98.7%
# 13          8.7%       0.0%     91.3%
# 14         20.5%       0.0%     79.5%
# 15         33.3%       0.0%     66.7%
# 16          6.4%       0.0%     93.6%
# 17         16.6%       0.0%     83.4%
# 18         18.3%       0.4%     81.4%
# 19         39.3%       0.0%     60.7%
# 20          6.2%       0.0%     93.8%
# 21          6.2%       0.0%     93.8%
# 22         10.9%       0.0%     89.1%
# 23         18.8%       0.0%     81.2%
# 24         10.3%       0.0%     89.7%
# 25         44.2%       0.0%     55.8%
# 26          9.7%       0.0%     90.3%
# 27         13.8%       0.0%     86.2%
# 28         68.8%       0.4%     30.8%
# 29          0.9%       0.0%     99.1%
# ...          ...        ...       ...
# 118703      0.0%       0.0%    100.0%
# 118704      0.0%       0.0%    100.0%
# 118705      0.0%       0.0%    100.0%
# 118706      0.0%       0.0%    100.0%
# 118707      0.0%       0.0%    100.0%
# 118708      0.0%       0.0%    100.0%
# 118709      0.0%       0.0%    100.0%
# 118710      0.0%       0.0%    100.0%
# 118711      0.0%       0.0%    100.0%
# 118712      0.0%       0.0%    100.0%
# 118713      0.0%       0.0%    100.0%
# 118714      0.0%       0.0%    100.0%
# 118715    100.0%       0.0%      0.0%
# 118716      0.0%       0.0%    100.0%
# 118717      0.0%       0.0%    100.0%
# 118718      0.0%       0.0%    100.0%
# 118719    100.0%       0.0%      0.0%
# 118720      0.0%       0.0%    100.0%
# 118721    100.0%       0.0%      0.0%
# 118722    100.0%       0.0%      0.0%
# 118723      0.0%       0.0%    100.0%
# 118724      0.0%       0.0%    100.0%
# 118725      0.0%       0.0%    100.0%
# 118726    100.0%       0.0%      0.0%
# 118727      0.0%       0.0%    100.0%
# 118728      0.0%       0.0%    100.0%
# 118729      0.0%       0.0%    100.0%
# 118730      0.0%       0.0%    100.0%
# 118731      0.0%       0.0%    100.0%
# 118732      0.0%       0.0%    100.0%
#
# [118733 rows x 5 columns]

# %%
porcentagem = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100).round(1))
                   .reset_index())
porcentagem
# Out:
#                                           nome_proponente  situacao_proposta  \
# 0                                CIRUFARMA COMERCIAL LTDA                985
# 1                          RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                            PNEUMAX LTDA                461
# 3                                   JOSE NERGINO SOBREIRA                395
# 4         TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                                VENDE TUDO MAGAZINE LTDA                343
# 6                                         DROGAFONTE LTDA                338
# 7                                 COMERCIAL MEDEIROS LTDA                328
# 8                          B J COMERCIO DE ALIMENTOS LTDA                328
# 9                                      CRM COMERCIAL LTDA                327
# 10                      ELMAR PROCESSAMENTO DE DADOS LTDA                322
# 11                MEGA MASTER COMERCIAL DE ALIMENTOS LTDA                306
# 12      NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
# 13                                     FIORI VEICOLO LTDA                299
# 14               LEIA COMERCIAL DE LIVROS E MAGAZINE LTDA                297
# 15                              CIRURGICA CAMPINENSE LTDA                285
# 16                              EDILANE DA COSTA CARVALHO                265
# 17                                            FARMAGUEDES                265
# 18                               NORDESTE HOSPITALAR LTDA                263
# 19                               DROGARIA DROGAVISTA LTDA                257
# 20                            CELIA FRANCISCO DE CARVALHO                256
# 21                          DENTALMED COMERCIO E REP LTDA                240
# 22             PONTUAL DISTRIBUIDORA DE MEDICAMENTOS LTDA                238
# 23      SUPRIMAIS COMERCIO E SERVICOS DE INFORMATICA LTDA                234
# 24       LECITA COMÉRCIO DE MATERIAL PARA ESCRITÓRIO LTDA                233
# 25                                  MD DISTRIBUIDORA LTDA                231
# 26         THOMAS JOSE BELTRAO DE ARAUJO ALBUQUERQUE - ME                226
# 27                             MEDFARMACY HOSPITALAR LTDA                225
# 28                              ADERALDO SERAFIM DE SOUSA                224
# 29                            IRAMILTON SATIRO DA NOBREGA                221
# ...                                                   ...                ...
# 118703                         PESQUEIRA DO NORDESTE-LTDA                  1
# 118704                     FRANKLIN DE OLIVEIRA CANTALICE                  1
# 118705  JUED COMERCIO E ASSISTENCIA DE EQUIPAMENTOS OD...                  1
# 118706                            JOSE ALEXANDRO DA SILVA                  1
# 118707                         FOLHA DE PESSOAL CLT SAUDE                  1
# 118708                     JAC-CONSTRUCOES E EVENTOS LTDA                  1
# 118709  MACIEL MARINHO SOCIEDADE INDIVIDUAL DE ADVOCAC...                  1
# 118710                             JOAO CANDIDO DA CASTRO                  1
# 118711                               OLI CONSTRUCOES LTDA                  1
# 118712  GEOVANE REFRIGERAÇÕES - VANDELÚCIA DE ARAÚJO R...                  1
# 118713                                 Ozias Bezerra Lima                  1
# 118714                   JOSE GABRIEL DE SOUZA DINIZ - ME                  1
# 118715                  INPREL CONSTRUÇÃO E SERVIÇOS LTDA                  1
# 118716            MANOEL JOSE DA SILVA PESSOA 05265992782                  1
# 118717                          ORLANDO INÁCIO DOS SANTOS                  1
# 118718                                 FERREIRA ADVOCACIA                  1
# 118719                  J & F PRESTADORA DE SERVIÇOS LTDA                  1
# 118720               JMS COMERCIO E SERVICOS PIRELLE - ME                  1
# 118721                                J. LIRA E CIA. LTDA                  1
# 118722  XMAIS MATERIAIS DE CONSTRUÇÃO LOC. INCORP. LTD...                  1
# 118723                       ROBERTO LUIZ NOBREGA CAMBOIM                  1
# 118724                         Gilson Marques de Oliveira                  1
# 118725                          PAULO CELESTINO DE PONTES                  1
# 118726                        PEDRO BARBOSA DO NASCIMENTO                  1
# 118727               GEOSISTEMAS ENG.E PLANEJAMENTO LTDA.                  1
# 118728      N.A.SOARES COMERCIO DE COMBUSTIVEL EIRELI EPP                  1
# 118729                         SILVIA ARAÚJO SIMPLICIO-ME                  1
# 118730    LOCADORA DE VEICULOS SANTA TEREZINHA EIRELI-EPP                  1
# 118731                       MANOEL RICARDO RAMALHO LEITE                  1
# 118732            MONIQUE POLIANA TORRES FRANÇAS DE BRITO                  1
#
#         Perdedora  Pesquisado  Vencedora
# 0             5.7         0.1       94.2
# 1            34.2         0.0       65.8
# 2            50.1         0.0       49.9
# 3             7.1         0.0       92.9
# 4             7.2         0.0       92.8
# 5            29.4         0.0       70.6
# 6             3.0         0.0       97.0
# 7            23.2         0.0       76.8
# 8             9.8         0.0       90.2
# 9             8.0         0.0       92.0
# 10           21.7         0.0       78.3
# 11           40.2         0.0       59.8
# 12            1.3         0.0       98.7
# 13            8.7         0.0       91.3
# 14           20.5         0.0       79.5
# 15           33.3         0.0       66.7
# 16            6.4         0.0       93.6
# 17           16.6         0.0       83.4
# 18           18.3         0.4       81.4
# 19           39.3         0.0       60.7
# 20            6.2         0.0       93.8
# 21            6.2         0.0       93.8
# 22           10.9         0.0       89.1
# 23           18.8         0.0       81.2
# 24           10.3         0.0       89.7
# 25           44.2         0.0       55.8
# 26            9.7         0.0       90.3
# 27           13.8         0.0       86.2
# 28           68.8         0.4       30.8
# 29            0.9         0.0       99.1
# ...           ...         ...        ...
# 118703        0.0         0.0      100.0
# 118704        0.0         0.0      100.0
# 118705        0.0         0.0      100.0
# 118706        0.0         0.0      100.0
# 118707        0.0         0.0      100.0
# 118708        0.0         0.0      100.0
# 118709        0.0         0.0      100.0
# 118710        0.0         0.0      100.0
# 118711        0.0         0.0      100.0
# 118712        0.0         0.0      100.0
# 118713        0.0         0.0      100.0
# 118714        0.0         0.0      100.0
# 118715      100.0         0.0        0.0
# 118716        0.0         0.0      100.0
# 118717        0.0         0.0      100.0
# 118718        0.0         0.0      100.0
# 118719      100.0         0.0        0.0
# 118720        0.0         0.0      100.0
# 118721      100.0         0.0        0.0
# 118722      100.0         0.0        0.0
# 118723        0.0         0.0      100.0
# 118724        0.0         0.0      100.0
# 118725        0.0         0.0      100.0
# 118726      100.0         0.0        0.0
# 118727        0.0         0.0      100.0
# 118728        0.0         0.0      100.0
# 118729        0.0         0.0      100.0
# 118730        0.0         0.0      100.0
# 118731        0.0         0.0      100.0
# 118732        0.0         0.0      100.0
#
# [118733 rows x 5 columns]

# %%
porcentagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118733 entries, 0 to 118732
# Data columns (total 5 columns):
# nome_proponente      118733 non-null object
# situacao_proposta    118733 non-null int64
# Perdedora            118733 non-null object
# Pesquisado           118733 non-null object
# Vencedora            118733 non-null object
# dtypes: int64(1), object(4)
# memory usage: 4.5+ MB

# %%
porcentagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118733 entries, 0 to 118732
# Data columns (total 5 columns):
# nome_proponente      118733 non-null object
# situacao_proposta    118733 non-null int64
# Perdedora            118733 non-null float64
# Pesquisado           118733 non-null float64
# Vencedora            118733 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 4.5+ MB

# %%
propostas = porcentagem[:10]
propostas
# Out:
#                                    nome_proponente  situacao_proposta  \
# 0                         CIRUFARMA COMERCIAL LTDA                985
# 1                   RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                     PNEUMAX LTDA                461
# 3                            JOSE NERGINO SOBREIRA                395
# 4  TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                         VENDE TUDO MAGAZINE LTDA                343
# 6                                  DROGAFONTE LTDA                338
# 7                          COMERCIAL MEDEIROS LTDA                328
# 8                   B J COMERCIO DE ALIMENTOS LTDA                328
# 9                               CRM COMERCIAL LTDA                327
#
#   Perdedora Pesquisado Vencedora
# 0      5.7%       0.1%     94.2%
# 1     34.2%       0.0%     65.8%
# 2     50.1%       0.0%     49.9%
# 3      7.1%       0.0%     92.9%
# 4      7.2%       0.0%     92.8%
# 5     29.4%       0.0%     70.6%
# 6      3.0%       0.0%     97.0%
# 7     23.2%       0.0%     76.8%
# 8      9.8%       0.0%     90.2%
# 9      8.0%       0.0%     92.0%

# %%
propostas = porcentagem[:10]
propostas
# Out:
#                                    nome_proponente  situacao_proposta  \
# 0                         CIRUFARMA COMERCIAL LTDA                985
# 1                   RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                     PNEUMAX LTDA                461
# 3                            JOSE NERGINO SOBREIRA                395
# 4  TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                         VENDE TUDO MAGAZINE LTDA                343
# 6                                  DROGAFONTE LTDA                338
# 7                          COMERCIAL MEDEIROS LTDA                328
# 8                   B J COMERCIO DE ALIMENTOS LTDA                328
# 9                               CRM COMERCIAL LTDA                327
#
#    Perdedora  Pesquisado  Vencedora
# 0        5.7         0.1       94.2
# 1       34.2         0.0       65.8
# 2       50.1         0.0       49.9
# 3        7.1         0.0       92.9
# 4        7.2         0.0       92.8
# 5       29.4         0.0       70.6
# 6        3.0         0.0       97.0
# 7       23.2         0.0       76.8
# 8        9.8         0.0       90.2
# 9        8.0         0.0       92.0

# %%
propostas.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
propostas.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
propostas.plot(x="nome_proponente", y=["Vencedora","Perdedora"], kind="barh").invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-89b9d31cb34c> in <module>
# ----> 1 propostas.plot(x="nome_proponente", y=["Vencedora","Perdedora"], kind="barh").invert_yaxis()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou
# Out:
#                                        nome_proponente  situacao_proposta  \
# 93                         RITA DE ANDRADE VIEIRA - ME                139
# 112                     COMPANHIA PARAIBANA DE COMÉDIA                121
# 29                         IRAMILTON SATIRO DA NOBREGA                221
# 36             JOSE WALTER DA COSTA ME - J C PRODUÇÕES                203
# 45                              ELFA MEDICAMENTOS LTDA                189
# 246               FRANCISCO VIVALDO JACOME DE OLIVEIRA                 84
# 276                       JOSELIA MARIA DE SOUSA RAMOS                 80
# 250                                          CIRUFARMA                 84
# 235                 INITUS CONSULTORES ASSOCIADOS LTDA                 85
# 12   NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
#
#     Perdedora Pesquisado Vencedora
# 93       0.7%       0.0%     99.3%
# 112      0.8%       0.0%     99.2%
# 29       0.9%       0.0%     99.1%
# 36       1.0%       0.0%     99.0%
# 45       1.1%       0.0%     98.9%
# 246      1.2%       0.0%     98.8%
# 276      1.2%       0.0%     98.8%
# 250      1.2%       0.0%     98.8%
# 235      1.2%       0.0%     98.8%
# 12       1.3%       0.0%     98.7%

# %%
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou
# Out:
#                                          nome_proponente  situacao_proposta  \
# 59366                                JOSE FELIX SOBRINHO                  2
# 69758                            ELENO FRANCISCO DE MELO                  1
# 69871                           Daniel da Silva Herminio                  1
# 69870                       JOSE WILKER CASTRICIANO NETO                  1
# 69869                          MARIA DA GLÓRIA DE ARAÚJO                  1
# 69868                  MICHAEL ALVES BITTENCOURT DE MELO                  1
# 69863                         JOSUE LOPES GUIMARÃES NETO                  1
# 69862                               FLAVIO BARBOSA VITOR                  1
# 69861  COOPERATIVA PAULISTA DE TRABALHO DOS PROFISSIO...                  1
# 69860                MARIA DO CEU FELIX DE ARAUJO ABILIO                  1
#
#        Perdedora  Pesquisado  Vencedora
# 59366        0.0         0.0      100.0
# 69758        0.0         0.0      100.0
# 69871        0.0         0.0      100.0
# 69870        0.0         0.0      100.0
# 69869        0.0         0.0      100.0
# 69868        0.0         0.0      100.0
# 69863        0.0         0.0      100.0
# 69862        0.0         0.0      100.0
# 69861        0.0         0.0      100.0
# 69860        0.0         0.0      100.0

# %%
ganhou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 59366 to 69860
# Data columns (total 5 columns):
# nome_proponente      10 non-null object
# situacao_proposta    10 non-null int64
# Perdedora            10 non-null float64
# Pesquisado           10 non-null float64
# Vencedora            10 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 480.0+ bytes

# %%
['Perdedora'] = propostas['Perdedora'].astype(float)
['Vencedora'] = propostas['Vencedora'].astype(float)
# Out:
#   File "<ipython-input-18-23cd0faacf77>", line 1
#     ['Perdedora'] = propostas['Perdedora'].astype(float)
#                                                         ^
# SyntaxError: can't assign to literal

# %%
perdeu = porcentagem.sort_values(by='Perdedora', ascending=False)[:10]
perdeu
# Out:
#                                  nome_proponente  situacao_proposta Perdedora  \
# 716    F&B COMERCIO ATACADISTA DE ALIMENTOS LTDA                 45     97.8%
# 709                     TECNOVIDA COMERCIAL LTDA                 45     97.8%
# 748                                     AC PNEUS                 44     97.7%
# 1249                  CONSTRUTORA CACHOEIRA LTDA                 32     96.9%
# 1345                       SETA CONSTRUCOES LTDA                 31     96.8%
# 259                      ERISVALDO GOMES DE MELO                 82     96.3%
# 1658                      PROCOM ENGENHARIA LTDA                 26     96.2%
# 1775                   AC COMÉRCIO DE PNEUS LTDA                 25     96.0%
# 1924             JONABIA NOBREGA DE LUCENA SILVA                 24     95.8%
# 1950  SÃO JOÉ EMPREENDIMENTOS DE CONTRUÇÕES LTDA                 24     95.8%
#
#      Pesquisado Vencedora
# 716        0.0%      2.2%
# 709        0.0%      2.2%
# 748        0.0%      2.3%
# 1249       0.0%      3.1%
# 1345       0.0%      3.2%
# 259        0.0%      3.7%
# 1658       0.0%      3.8%
# 1775       0.0%      4.0%
# 1924       0.0%      4.2%
# 1950       0.0%      4.2%

# %%
perdeu = porcentagem.sort_values(by='Perdedora', ascending=False)[:10]
perdeu
# Out:
#                                nome_proponente  situacao_proposta  Perdedora  \
# 59366  MULTICONSULT PLANEJ. ENG. E ARQUITETURA                  2      100.0
# 68527                JOSE DOS SANTOS BEZERRA *                  1      100.0
# 68899                 NERVALDO DA COSTA PESSOA                  1      100.0
# 68904                       Erica Elisa NicKel                  1      100.0
# 68908       KM DISTRIBUIDORA DE ALIMENTOS LTDA                  1      100.0
# 68909                 CASA DAS FLORES LTDA  ME                  1      100.0
# 68910                 JOSE XAVIER DE ARAUJO ME                  1      100.0
# 68911       Centauros Produções e Eventos Ltda                  1      100.0
# 68912                 Gustavo Gadelha Suassuna                  1      100.0
# 68915                    JOSÉ ERONALDO DE MELO                  1      100.0
#
#        Pesquisado  Vencedora
# 59366         0.0        0.0
# 68527         0.0        0.0
# 68899         0.0        0.0
# 68904         0.0        0.0
# 68908         0.0        0.0
# 68909         0.0        0.0
# 68910         0.0        0.0
# 68911         0.0        0.0
# 68912         0.0        0.0
# 68915         0.0        0.0
