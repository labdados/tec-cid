# %% [markdown]
# # Análise dos maiores e menores vencedores
#     * Ranking da porcentagem de vitórias
#     * Ranking da porcentagem de derrotas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lic = pd.read_csv("propostas_licitacao.txt", sep="|", dtype={'cod_unidade_gestora': int,'numero_licitacao': str,'cod_tipo_licitacao': int,
                                                   'qtd_ofertada': int,'unidade_gestora': str, 'tipo_licitacao': str, 
                                                   'cpf_cnpj': str,'nome_proponente': str, 'situacao_proposta': str})

# %%
porcentagem = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100).round(1))
                   .reset_index())
porcentagem
# Out:
#                                           nome_proponente  situacao_proposta  \
# 0                                CIRUFARMA COMERCIAL LTDA                985
# 1                          RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                            PNEUMAX LTDA                461
# 3                                   JOSE NERGINO SOBREIRA                395
# 4         TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                                VENDE TUDO MAGAZINE LTDA                343
# 6                                         DROGAFONTE LTDA                338
# 7                                 COMERCIAL MEDEIROS LTDA                328
# 8                          B J COMERCIO DE ALIMENTOS LTDA                328
# 9                                      CRM COMERCIAL LTDA                327
# 10                      ELMAR PROCESSAMENTO DE DADOS LTDA                322
# ...

# %%
propostas = porcentagem[:10]
propostas.style.format({
    'Perdedora': '{0:.2f}%'.format,
    'Vencedora': '{0:.2f}%'.format,
    'Pesquisado': '{0:.2f}%'.format,
})
# Out:
# <style  type="text/css" >
# </style><table id="T_91ba059e_bfa8_11e9_8f32_707781d46ab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nome_proponente</th>        <th class="col_heading level0 col1" >situacao_proposta</th>        <th class="col_heading level0 col2" >Perdedora</th>        <th class="col_heading level0 col3" >Pesquisado</th>        <th class="col_heading level0 col4" >Vencedora</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_91ba059e_bfa8_11e9_8f32_707781d46ab2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_91ba059e_bfa8_11e9_8f32_707781d46ab2row0_col0" class="data row0 col0" >CIRUFARMA COMERCIAL LTDA</td>
#                         <td id="T_91ba059e_bfa8_11e9_8f32_707781d46ab2row0_col1" class="data row0 col1" >985</td>
#                         <td id="T_91ba059e_bfa8_11e9_8f32_707781d46ab2row0_col2" class="data row0 col2" >5.70%</td>
# ...

# %%
propostas.plot(x="nome_proponente", kind="barh").invert_yaxis()
plt.title("Top 10 da porcentagem de empresas que mais fizeram propostas de licitações em João Pessoa")
plt.ylabel('Unidades Gestoras')
plt.xlabel('Quantidade de licitações')
#falta ajeitar pra o xlabel fica mostrando com %
group_labels = ['control', 'cold treatment',
             'hot treatment', 'another treatment',
             'the last one']

ax.set_xticklabels(group_labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-847a70fbb09d> in <module>
#       7              'the last one']
#       8
# ----> 9 ax.set_xticklabels(group_labels)
#
# AttributeError: 'NoneType' object has no attribute 'set_xticklabels'

# %%
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou
# Out:
#                                          nome_proponente  situacao_proposta  \
# 59366  : CENTERDATA ANALISES DE SISTEMAS E SERVICOS L...                  2
# 69660                    MULTIPLA PRODUCAO CULTURAL LTDA                  1
# 69769  ASSOCIACAO RURAL ANTONIO AMORIM DE SOUSA DO SITIO                  1
# 69766                           CANDIDA PEREIRA DE SOUSA                  1
# 69765                           EUCLIDES ALVES DE ARAUJO                  1
# 69763            CASA DA SUSPENSAO PECAS E SERVICOS LTDA                  1
# 69762                    MARCOS AUR�LIO FERREIRA DE LIMA                  1
# 69761               FABIANA MENDES BATISTA DO NASCIMENTO                  1
# 69760               ANTONIO PEREIRA FERREIRA 06914569410                  1
# 69758   CONTEMIX COMERCIO RJ DE EQUIPAMENTOS EIRELI - ME                  1
#
#        Perdedora  Pesquisado  Vencedora
# 59366        0.0         0.0      100.0
# 69660        0.0         0.0      100.0
# ...

# %%
ganhou = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
ganhou.style.format({
    'Perdedora': '{0:.2f}%'.format,
    'Vencedora': '{0:.2f}%'.format,
    'Pesquisado': '{0:.2f}%'.format,
})
# Out:
# <style  type="text/css" >
# </style><table id="T_c284436c_bfa8_11e9_b90e_707781d46ab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nome_proponente</th>        <th class="col_heading level0 col1" >situacao_proposta</th>        <th class="col_heading level0 col2" >Perdedora</th>        <th class="col_heading level0 col3" >Pesquisado</th>        <th class="col_heading level0 col4" >Vencedora</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c284436c_bfa8_11e9_b90e_707781d46ab2level0_row0" class="row_heading level0 row0" >59366</th>
#                         <td id="T_c284436c_bfa8_11e9_b90e_707781d46ab2row0_col0" class="data row0 col0" >EDITORA D.C.L. DIF.CULTURADL DO LIVRO LTDA.</td>
#                         <td id="T_c284436c_bfa8_11e9_b90e_707781d46ab2row0_col1" class="data row0 col1" >2</td>
# ...

# %%
ganhou.plot(x="nome_proponente", kind="barh").invert_yaxis()

# %%
perdeu = porcentagem.sort_values(by='Vencedora', ascending=False)[:10]
perdeu.style.format({
    'Perdedora': '{0:.2f}%'.format,
    'Vencedora': '{0:.2f}%'.format,
    'Pesquisado': '{0:.2f}%'.format,
})
# Out:
# <style  type="text/css" >
# </style><table id="T_20e79402_bfa9_11e9_8fe2_707781d46ab2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nome_proponente</th>        <th class="col_heading level0 col1" >situacao_proposta</th>        <th class="col_heading level0 col2" >Perdedora</th>        <th class="col_heading level0 col3" >Pesquisado</th>        <th class="col_heading level0 col4" >Vencedora</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20e79402_bfa9_11e9_8fe2_707781d46ab2level0_row0" class="row_heading level0 row0" >59366</th>
#                         <td id="T_20e79402_bfa9_11e9_8fe2_707781d46ab2row0_col0" class="data row0 col0" >EDITORA D.C.L. DIF.CULTURADL DO LIVRO LTDA.</td>
#                         <td id="T_20e79402_bfa9_11e9_8fe2_707781d46ab2row0_col1" class="data row0 col1" >2</td>
# ...

# %%
perdeu.plot(x="nome_proponente", kind="barh").invert_yaxis()
