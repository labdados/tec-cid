# %% [markdown]
# # Análise dos maiores e menores vencedores
#     * Ranking da porcentagem de vitórias
#     * Ranking da porcentagem de derrotas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lic = pd.read_csv("propostas_licitacao.txt", sep="|", dtype={'cod_unidade_gestora': int,'numero_licitacao': str,'cod_tipo_licitacao': int,
                                                   'qtd_ofertada': int,'unidade_gestora': str, 'tipo_licitacao': str, 
                                                   'cpf_cnpj': str,'nome_proponente': str, 'situacao_proposta': str})

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-a84c0541e888> in <module>
# ----> 1 import seaborn as sns
#
# ~\Anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# ~\Anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       3 import functools
#       4 import matplotlib as mpl
# ----> 5 from . import palettes, _orig_rc_params
#       6
#       7
#
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in <module>
#      10 from .external.six.moves import range
#      11
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .colors import xkcd_rgb, crayons
#      14
#
# ~\Anaconda3\lib\site-packages\seaborn\utils.py in <module>
#       5
#       6 import numpy as np
# ...

# %%
frequencies = [6, -16, 75, 160, 244, 260, 145, 73, 16, 4, 1]

freq_series = pd.Series(frequencies)

y_labels = [108300.0, 110540.0, 112780.0, 115020.0, 117260.0, 119500.0, 
            121740.0, 123980.0, 126220.0, 128460.0, 130700.0]

# Plot the figure.
plt.figure(figsize=(12, 8))
ax = freq_series.plot(kind='barh')
ax.set_title('Amount Frequency')
ax.set_xlabel('Frequency')
ax.set_ylabel('Amount ($)')
ax.set_yticklabels(y_labels)
ax.set_xlim(-40, 300) # expand xlim to make labels easier to read

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:.1f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

# %%
N = 10
gv = ganhou.Vencedora
pv = perdeu.Vencedora

fig, ax = plt.subplots()

ind = pd.np.arange(N)    # the x locations for the groups
width = 0.35         # the width of the bars
p1 = ax.bar(ind, gv, width, bottom=5)

gp = ganhou.Perdedora
pp = perdeu.Perdedora
p2 = ax.bar(ind + width, gp, width, bottom=5)

ax.set_title('Top 10 das empresas que mais venceram licitação na PB')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(ganhou.nome_proponente, rotation=90)

ax.legend((p1[0], p2[0]), ('Vencedora', 'Perdedora'))

plt.show()

# %%
ganhou
# Out:
#                                        nome_proponente  situacao_proposta  \
# 93                         RITA DE ANDRADE VIEIRA - ME                139
# 112                     COMPANHIA PARAIBANA DE COMÉDIA                121
# 29                         IRAMILTON SATIRO DA NOBREGA                221
# 35             JOSE WALTER DA COSTA ME - J C PRODUÇÕES                203
# 46                              ELFA MEDICAMENTOS LTDA                189
# 276                       JOSELIA MARIA DE SOUSA RAMOS                 80
# 235                 INITUS CONSULTORES ASSOCIADOS LTDA                 85
# 245               FRANCISCO VIVALDO JACOME DE OLIVEIRA                 84
# 250                                          CIRUFARMA                 84
# 12   NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
#
#     Perdedora Pesquisado Vencedora
# 93       0.7%       0.0%     99.3%
# 112      0.8%       0.0%     99.2%
# 29       0.9%       0.0%     99.1%
# ...

# %%
df = pd.DataFrame(dict(graph=ganhou.nome_proponente,
                           n=ganhou.Vencedora, m=ganhou.Perdedora)) 

ind = pd.np.arange(len(df))
width = 0.4

fig, ax = plt.subplots()
ax.barh(ind, df.n, width, label='Venceu')
ax.barh(ind + width, df.m, width, label='Perdeu')
ax.set_title('Top 10 das empresas que mais venceram licitação na PB')

ax.set(yticks=ind + width, yticklabels=df.graph, ylim=[2*width - 1, len(df)])
ax.legend()

plt.show()

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = ganhou.situacao_proposta
bars2 = ganhou.Vencedora
bars3 = ganhou.Perdedora
 
# Set position of bar on X axis
r1 = pd.np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Total')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Ganhou')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Perdeu')
 
# Add xticks on the middle of the group bars
plt.xticks([r + barWidth for r in range(len(bars1))], ganhou.nome_proponente, rotation=90)
plt.title("Top 10 das empresas que mais venceram licitação na PB")

# Create legend & Show graphic
plt.legend()
plt.show()

# %%
# Create bars
barWidth = 1.9
bars1 = ganhou.situacao_proposta
bars2 = ganhou.Vencedora
bars3 = ganhou.Perdedora
 
# The X position of bars
r1 = pd.np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Create barplot
plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Total')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='Ganhou')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='Perdeu')
# Note: the barplot could be created easily. See the barplot section for other examples.
 
# Create legend
plt.legend()
 
# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ganhou.nome_proponente, rotation=90)
 
# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']
 
# Text on the top of each barplot
for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)
 
# Adjust the margins
plt.subplots_adjust(bottom= 0.2, top = 0.98)
 
# Show graphic
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d72c6cbea7a7> in <module>
#      20
#      21 # Text below each barplot with a rotation at 90°
# ---> 22 plt.xticks([r + barWidth for r in range(len(r4))], ganhou.nome_proponente, rotation=90)
#      23
#      24 # Create labels
#
# NameError: name 'r4' is not defined

# %%
d = lic['nome_proponente'].value_counts().to_frame()[:3]

# %%
s = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100).round(1).astype(str) + '%')
                   .reset_index())

# %%
perdeu = s.sort_values(by='Perdedora',ascending=False)[:10]
perdeu
# Out:
#                                 nome_proponente  situacao_proposta Perdedora  \
# 707                    TECNOVIDA COMERCIAL LTDA                 45     97.8%
# 716   F&B COMERCIO ATACADISTA DE ALIMENTOS LTDA                 45     97.8%
# 728                                    AC PNEUS                 44     97.7%
# 1273                 CONSTRUTORA CACHOEIRA LTDA                 32     96.9%
# 1361                      SETA CONSTRUCOES LTDA                 31     96.8%
# 259                     ERISVALDO GOMES DE MELO                 82     96.3%
# 1662                     PROCOM ENGENHARIA LTDA                 26     96.2%
# 1862                  AC COMÉRCIO DE PNEUS LTDA                 25     96.0%
# 1977            JONABIA NOBREGA DE LUCENA SILVA                 24     95.8%
# 1921                    SUPERMERCDO SOARES LTDA                 24     95.8%
#
#      Pesquisado Vencedora
# 707        0.0%      2.2%
# 716        0.0%      2.2%
# 728        0.0%      2.3%
# ...

# %%
ganhou = s.sort_values(by='Vencedora',ascending=False)[:10]
ganhou
# Out:
#                                        nome_proponente  situacao_proposta  \
# 93                         RITA DE ANDRADE VIEIRA - ME                139
# 112                     COMPANHIA PARAIBANA DE COMÉDIA                121
# 29                         IRAMILTON SATIRO DA NOBREGA                221
# 35             JOSE WALTER DA COSTA ME - J C PRODUÇÕES                203
# 46                              ELFA MEDICAMENTOS LTDA                189
# 276                       JOSELIA MARIA DE SOUSA RAMOS                 80
# 235                 INITUS CONSULTORES ASSOCIADOS LTDA                 85
# 245               FRANCISCO VIVALDO JACOME DE OLIVEIRA                 84
# 250                                          CIRUFARMA                 84
# 12   NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...                306
#
#     Perdedora Pesquisado Vencedora
# 93       0.7%       0.0%     99.3%
# 112      0.8%       0.0%     99.2%
# 29       0.9%       0.0%     99.1%
# ...

# %%
ganhou.nome_proponente
# Out:
# 93                           RITA DE ANDRADE VIEIRA - ME
# 113                       COMPANHIA PARAIBANA DE COMÉDIA
# 29                           IRAMILTON SATIRO DA NOBREGA
# 34               JOSE WALTER DA COSTA ME - J C PRODUÇÕES
# 46                                ELFA MEDICAMENTOS LTDA
# 242                 FRANCISCO VIVALDO JACOME DE OLIVEIRA
# 236                   INITUS CONSULTORES ASSOCIADOS LTDA
# 273                         JOSELIA MARIA DE SOUSA RAMOS
# 243                                            CIRUFARMA
# 11     NNMED-DISTRIBUICAO, IMPORTACAO E EXPORTACAO DE...
# Name: nome_proponente, dtype: object

# %%
df2 = (lic['nome_proponente'].value_counts().rename_axis('nome_proponente').to_frame('situacao_proposta')
                   .join(pd.crosstab(lic['nome_proponente'], lic['situacao_proposta'], normalize=0).mul(100))
                   .reset_index())
df2


porcent = p.mul(100).round(1).astype(str) + '%'
# Out:
#                                           nome_proponente  situacao_proposta  \
# 0                                CIRUFARMA COMERCIAL LTDA                985
# 1                          RAIMUNDO ADELMAR FONSECA PIRES                488
# 2                                            PNEUMAX LTDA                461
# 3                                   JOSE NERGINO SOBREIRA                395
# 4         TECNOCENTER MATERIAIS MEDICOS HOSPITALARES LTDA                389
# 5                                VENDE TUDO MAGAZINE LTDA                343
# 6                                         DROGAFONTE LTDA                338
# 7                                 COMERCIAL MEDEIROS LTDA                328
# 8                          B J COMERCIO DE ALIMENTOS LTDA                328
# 9                                      CRM COMERCIAL LTDA                327
# 10                      ELMAR PROCESSAMENTO DE DADOS LTDA                322
# ...

# %%
#Verificar quanto uma empresa/ganhou perdeu das licitações que ela fez.
lic.groupby('nome_proponente').situacao_proposta.agg(lambda g: g.eq('Vencedora', 'Perdedora').count())
df1 = lic['nome_proponente'].value_counts().to_frame('games')
df = df1.join(pd.crosstab(df['player'], df['games'], normalize=0).mul(100))


df2 = (df['player'].value_counts().rename_axis('player').to_frame('games')
                   .join(pd.crosstab(df['player'], df['games'], normalize=0).mul(100))
                   .reset_index())

print (df2)
  player  games  has won   lost
0   John      4     50.0   50.0
1   Jose      2    100.0    0.0
2   Adam      1      0.0  100.0

df2 = (df['player'].value_counts().rename_axis('player').to_frame('games')
                   .join(pd.crosstab(df['player'], df['games'], normalize=0).mul(100))
                   .reset_index())

print (df2)
  player  games  has won   lost
0   John      4     50.0   50.0
1   Jose      2    100.0    0.0
2   Adam      1      0.0  100.0
# Out:
# nome_proponente
# (CONQUISTA) - COMERCIO DE EQUIPAMENTOS LTDA                                    1
# /MARIA JOSÉ FAUSTINO DOS SANTOS                                                1
# 0 e L RENT CAR LOCADORA DE VEILULO                                             2
# 01 - GABINETE DO PREFEITO.                                                     1
# 08525867000172                                                                 1
# 1 CARTORIO CAMPINA GRANDE, 2 CARTO. CAMPINA GRANDE E OUTROS                    1
# 1001 IDEIAS - ARMANDO RODRIGUES DE OLIVEIRA                                   17
# 1001 IDEIAS MARKETING,PRODUCOES PUBLIC.ARMANDO R.OLIVEIRA                      2
# 1001 IDÉIAS - ARMANDO RODRIGUES DE OLIVEIRA                                    4
# 1001 IDÉIAS PRODUÇÕES                                                          1
# 1001 SERVICOS ENGENHARIA E CONSTRUCAO LTDA                                    14
# ...

# %%
lic.groupby('nome_proponente').situacao_proposta.agg(lambda g: g.eq('Vencedora', 'Perdedora').value_counts()).to_frame()
# Out:
#                                                    situacao_proposta
# nome_proponente
# (CONQUISTA) - COMERCIO DE EQUIPAMENTOS LTDA                        1
# /MARIA JOSÉ FAUSTINO DOS SANTOS                                    1
# 0 e L RENT CAR LOCADORA DE VEILULO                                 2
# 01 - GABINETE DO PREFEITO.                                         1
# 08525867000172                                                     1
# 1 CARTORIO CAMPINA GRANDE, 2 CARTO. CAMPINA GRA...                 1
# 1001 IDEIAS - ARMANDO RODRIGUES DE OLIVEIRA                  [14, 3]
# 1001 IDEIAS MARKETING,PRODUCOES PUBLIC.ARMANDO ...                 2
# 1001 IDÉIAS - ARMANDO RODRIGUES DE OLIVEIRA                   [2, 2]
# 1001 IDÉIAS PRODUÇÕES                                              1
# 1001 SERVICOS ENGENHARIA E CONSTRUCAO LTDA                    [9, 5]
# 1001 SERVICOS ENGENHARIA E CONSTRUCAO LTDA - EPP                   3
# ...

# %%
v.plot(kind='barh', x='nome_proponente', y='percent').invert_yaxis()
plt.title("Top 10 das empresas que mais venceram licitação na PB")
plt.ylabel('Empresas')
plt.xlabel('Quantidade de licitações')
# Out:
# Text(0.5, 0, 'Quantidade de licitações')

# %%
p.plot(kind='barh', x='nome_proponente', y='percent').invert_yaxis()
plt.title("Top 10 das empresas que mais venceram licitação na PB")
plt.ylabel('Empresas')
plt.xlabel('Quantidade de licitações')
# Out:
# Text(0.5, 0, 'Quantidade de licitações')

# %%
#Verificar quais os maiores vencedores e quais os menores vencedores.
perdedoras = lic['nome_proponente'].groupby(lic['situacao_proposta']).get_group('Perdedora')
p = perdedoras.value_counts(normalize=True)[:10]
porcent = p.mul(100).round(1).astype(str) + '%'
porcent
# Out:
# PNEUMAX LTDA                               0.2%
# BELARMINO SERVIÇOS DE CONSTRUÇÃO Ltda      0.1%
# RAIMUNDO ADELMAR FONSECA PIRES             0.1%
# ADERALDO SERAFIM DE SOUSA                  0.1%
# MEGA MASTER COMERCIAL DE ALIMENTOS LTDA    0.1%
# MILTONIZIA CORREIA LIMA BORBA              0.1%
# WILLIAMS RANGEL LOBO                       0.1%
# JOAO PAULO ARAUJO DOS SANTOS               0.1%
# COMERCIAL CAMPINENSE DE CEREAIS LTDA       0.1%
# CONSTRUTORA MOURIAH LTDA                   0.1%
# Name: nome_proponente, dtype: object
