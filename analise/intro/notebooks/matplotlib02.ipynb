# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
cidades = ['João Pessoa', 'Campina Grande', 'Rio Tinto', 'Salgado de São Félix', 'Areia', 'Cacimba de Dentro', 'São José de Piranhas', 'Juru', 'São José da Lagoa Tapada', 'Emas']

# %%
lic_cidade = [534,324,312,310,290,295,200,212,100,10]

# %%
plt.barh(cidades,lic_cidade,color='pink')
plt.title("Top 10 das cidades que mais fazem licitação na PB")
# Out:
# Text(0.5, 1.0, 'Top 10 das cidades que mais fazem licitação na PB')

# %%
names=['ID Unidade Gestora', 'Unidade Gestora','N° da licitação','Código tipo licitação','Tipo de licitação', 'Data da homologação','Código tipo objeto', 'Tipo do objeto','Valor da licitação','Observações']
lic = pd.read_csv('arquivos/licitacao.csv', names=names)
# Out:
# C:\Users\mirianbatista\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (2,3,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lic
# Out:
#                                        ID Unidade Gestora  \
# 0                                                  101001
# 1                                                  101001
# 2                                                  101003
# 3                                                  101003
# 4                                                  101004
# 5                                                  101004
# 6                                                  101004
# 7                                                  101004
# 8                                                  101005
# 9                                                  101005
# 10                                                 101005
# 11                                                 101005
# 12                                                 101006
# 13                                                 101006
# 14                                                 101006
# ...

# %%
pd.unique(lic('Unidade Gestora'))
# Out:
# array(['ID Unidade Gestora'], dtype=object)

# %%
lic['Rank_by_cities'] = lic['Unidade Gestora'].rank(ascending=False)

# %%
lic
# Out:
#                                        ID Unidade Gestora  \
# 0                                                  101001
# 1                                                  101001
# 2                                                  101003
# 3                                                  101003
# 4                                                  101004
# 5                                                  101004
# 6                                                  101004
# 7                                                  101004
# 8                                                  101005
# 9                                                  101005
# 10                                                 101005
# 11                                                 101005
# 12                                                 101006
# 13                                                 101006
# 14                                                 101006
# ...

# %%
lic.groupby('Unidade Gestora').count()
# Out:
#                                                     ID Unidade Gestora  \
# Unidade Gestora
#  01 do tipo van                                                      1
#  12000 litros                                                        1
#  22 de feverei                                                       1
#  27000 litros                                                        1
#  4 portas                                                            1
#  4000 litros                                                         1
#  ASMA E RENITE (HDL.15)                                              1
#  Bom Jesus                                                           1
#  CONFORME ESPECIFICAÇÕES                                             1
#  CRAS deste Município.                                               1
#  Creche                                                              1
#  DE FEV/2006 A DEZ/2006                                              1
# ...

# %%
lic.count()
# Out:
# ID Unidade Gestora       199873
# Unidade Gestora          199093
# N° da licitação          198958
# Código tipo licitação    198936
# Tipo de licitação        198930
# Data da homologação      198927
# Código tipo objeto       198927
# Tipo do objeto           198927
# Valor da licitação       197618
# Observações              194219
# Rank_by_cities           199093
# dtype: int64

# %%
lic.mode()
# Out:
#   ID Unidade Gestora                   Unidade Gestora N° da licitação  \
# 0             603095  Fundação Cultural de João Pessoa       000012017
#
#   Código tipo licitação Tipo de licitação Data da homologação  \
# 0                     3           Convite          01/01/2018
#
#   Código tipo objeto      Tipo do objeto Valor da licitação  \
# 0                  2  Compras e Serviços              30000
#
#                                          Observações  Rank_by_cities
# 0  CONTRATACAO DOS PRESTADORES DE SERVICOS ESPECI...        185390.5

# %%
lic.mode(axis=1)
# Out:
# C:\Users\mirianbatista\Anaconda3\lib\site-packages\pandas\core\algorithms.py:829: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   warn("Unable to sort modes: {error}".format(error=e))
# C:\Users\mirianbatista\Anaconda3\lib\site-packages\pandas\core\algorithms.py:829: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   warn("Unable to sort modes: {error}".format(error=e))
#                                                        0   \
# 0                                                   28000
# 1                                                   18000
# 2                                      Compras e Serviços
# 3                                                   19200
# 4                                                   24000
# 5                                      Compras e Serviços
# 6                                      Compras e Serviços
# ...

# %%
lic.groupby('Unidade Gestora').unidade_gestora.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-746bf4d440fa> in <module>
# ----> 1 lic.groupby('Unidade Gestora').unidade_gestora.count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'unidade_gestora'

# %%
lic
# Out:
#                                        ID Unidade Gestora  \
# 0                                                  101001
# 1                                                  101001
# 2                                                  101003
# 3                                                  101003
# 4                                                  101004
# 5                                                  101004
# 6                                                  101004
# 7                                                  101004
# 8                                                  101005
# 9                                                  101005
# 10                                                 101005
# 11                                                 101005
# 12                                                 101006
# 13                                                 101006
# 14                                                 101006
# ...

# %%
ranking_municipio = lic['Unidade Gestora'].value_counts()

# %%
plt.barh(ranking_municipio,color='pink')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8f9d43715042> in <module>
# ----> 1 plt.barh(ranking_municipio,color='pink')
#
# TypeError: barh() missing 1 required positional argument: 'width'

# %%
lic['Unidade Gestora'].value_counts().plot.barh()

# %%
a = lic['Unidade Gestora'].value_counts()

x = list(a.index)
y = list(a)

fig, ax = plt.subplots()    
width = 0.75 # the width of the bars 
ind = np.arange(len(y))  # the x locations for the groups
ax.barh(ind, y, width, color="blue")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(x, minor=False)
for i, v in enumerate(y):
    ax.text(v + .25, i + .25, str(v), color='blue', fontweight='bold') #add value labels into bar
plt.title('title')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
lic['Unidade Gestora'].value_counts().plot.barh().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fc3479c5be97> in <module>
# ----> 1 lic['Unidade Gestora'].value_counts().plot.barh().head(5)
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'

# %%
municipio = lic['Unidade Gestora'].value_counts().plot.barh()

# %%
municipio.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-64058455e133> in <module>
# ----> 1 municipio.head(10)
#
# AttributeError: 'AxesSubplot' object has no attribute 'head'

# %%
lic['Unidade Gestora'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Fundação Cultural de João Pessoa              6932
# Prefeitura Municipal de João Pessoa           5947
# Prefeitura Municipal de Campina Grande        4679
# Fundo Municipal de Saúde de Campina Grande    3953
# Prefeitura Municipal de Santa Rita            3022
# Prefeitura Municipal de Patos                 2701
# Prefeitura Municipal de Cabedelo              2301
# Prefeitura Municipal de Sousa                 2205
# Fundo Municipal de Saúde de João Pessoa       2139
# Prefeitura Municipal de Pombal                2133
# Name: Unidade Gestora, dtype: int64

# %%
lic['Unidade Gestora'].value_counts()[:10].plot(kind='barh')
plt.title("Top 10 das cidades que mais fazem licitação na PB")
plt.ylabel('Cidades')
plt.xlabel('Quantidade de licitações')
# Out:
# Text(0.5, 0, 'Quantidade de licitações')
