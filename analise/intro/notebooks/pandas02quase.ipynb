# %%
import pandas as pd

# %%
lic = pd.read_csv('arquivos/licitacao.csv', names=['teste'])

# %%
licitacao = lic["teste"].str.split(",", n = 9, expand = True)

# %%
licitacao
# Out:
#                                                         0  \
# 0                                            ﻿cd_ugestora
# 1                                                  101001
# 2                                                  101001
# 3                                                  101003
# 4                                                  101003
# 5                                                  101004
# 6                                                  101004
# 7                                                  101004
# 8                                                  101004
# 9                                                  101005
# 10                                                 101005
# 11                                                 101005
# 12                                                 101005
# 13                                                 101006
# 14                                                 101006
# ...
